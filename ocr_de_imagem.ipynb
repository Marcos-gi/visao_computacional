# %% [markdown]
# <a href="https://colab.research.google.com/github/Marcos-gi/visao_computacional/blob/main/ocr_de_imagem.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install opencv-python
# !sudo apt install tesseract-ocr
# !pip install pytesseract==0.3.9
# Out:
# Collecting pytesseract==0.3.9
#   Downloading pytesseract-0.3.9-py2.py3-none-any.whl (14 kB)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.10/dist-packages (from pytesseract==0.3.9) (23.2)
# Requirement already satisfied: Pillow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from pytesseract==0.3.9) (9.4.0)
# Installing collected packages: pytesseract
# Successfully installed pytesseract-0.3.9

# %%
import pytesseract
import numpy as np
import cv2
from google.colab.patches import cv2_imshow

# %%
img = cv2.imread('/content/BB Search índices.jpg')
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=799x469>

# %%
texto = pytesseract.image_to_string(img)
print(texto)
# Out:
# 7. E quais bases de dados estao disponibilizadas no BB Search?
# As bases estao sempre sendo ampliadas, mas nesse momento temos dados das seguintes
# bases (origens):
#
# a. bb_atende: ocorréncias do BB Atende abertas ou resolvidas pela CRBB OU encaminhadas
# para Ditec.
#
# b. bb_atende_carteira: apresenta a visdo carteira dos clientes das ocorréncias oriundas da
# CRBB.
#
# c. bb_atende_sac: ocorréncias de TI: ocorréncias registradas ou encaminhadas para 0 SAC.
#
# d. bb_atende_sac_ouvi: ocorréncias registradas na ouvidoria oriundas do suporte técnico ou
# orgaos externos e encaminhadas para a Ditec.
#
# e. bb_interagao_ce: ocorréncias do Interagdo (GST!) do publico Clientes Externos
#
# f. bb_interagao_geral: ocorréncias do Interagao (GST!) de clientes Internos e Externos
#
# g. kairos_conha3imentos: interno - utilizado pelo time matrix
#
# h. lojas_app_dados: contém registros dos comentarios feitos nas lojas de aplicativos
# i
#
#
#
# ._ midias_sociais: comentarios feitos no Twitter e Facebook
#
# j. whatsapp_consolidado: registros dos atendimentos realizados no whatsapp com o campo
# de conversa consolidado
#
# k. whasapp_falecom: registros individuals do falecom e whatsapp com cada linha do diélogo
# separada
#
# |. Matomo_erros: Ocorréncias de erros registrados no APJ Web, APF Web, Plataforma e
# Mobile (em breve).
